# %% [markdown]
# COVID- 19 DATASET ANALYSIS
#
# IN THIS PROJECT I WILL PERFROM ANALYSIS ON THE COVID-DATA SET THAT WAS LAST UPDATED FEB 2021 TAKEN FROM KAGGEL

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\27823\Downloads\archive\covid_19_data.csv")

# %%
data
# Out:
#            SNo ObservationDate              State          Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 236012  236013      02/27/2021  Zaporizhia Oblast         Ukraine
# 236013  236014      02/27/2021            Zeeland     Netherlands
# 236014  236015      02/27/2021           Zhejiang  Mainland China
# 236015  236016      02/27/2021    Zhytomyr Oblast         Ukraine
# 236016  236017      02/27/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed   Deaths  Recovered
# 0           1/22/2020 17:00       1.00     0.00       0.00
# ...

# %% [markdown]
# Count Instances

# %%
data.count()
# Out:
# SNo                236017
# ObservationDate    236017
# State              173972
# Region             236017
# Last Update        236017
# Confirmed          236017
# Deaths             236017
# Recovered          236017
# dtype: int64

# %%
data.isnull().sum() #null values
# Out:
# SNo                    0
# ObservationDate        0
# State              62045
# Region                 0
# Last Update            0
# Confirmed              0
# Deaths                 0
# Recovered              0
# dtype: int64

# %% [markdown]
# Plotting

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show() # displaying  null values

# %%
data.head()
# Out:
#    SNo ObservationDate      State          Region      Last Update  Confirmed  \
# 0    1      01/22/2020      Anhui  Mainland China  1/22/2020 17:00       1.00
# 1    2      01/22/2020    Beijing  Mainland China  1/22/2020 17:00      14.00
# 2    3      01/22/2020  Chongqing  Mainland China  1/22/2020 17:00       6.00
# 3    4      01/22/2020     Fujian  Mainland China  1/22/2020 17:00       1.00
# 4    5      01/22/2020      Gansu  Mainland China  1/22/2020 17:00       0.00
#
#    Deaths  Recovered
# 0    0.00       0.00
# 1    0.00       0.00
# 2    0.00       0.00
# 3    0.00       0.00
# 4    0.00       0.00

# %% [markdown]
# Displaying the Confirmed, Deaths, and Recovered cases for each each region

# %%
data.groupby('Region').sum()
# Out:
#                                      SNo     Confirmed     Deaths  \
# Region
#  Azerbaijan                         2664          1.00       0.00
# ('St. Martin',)                     4675          2.00       0.00
# Afghanistan                     37614761 11,651,049.00 434,582.00
# Albania                         37571690  8,319,315.00 170,096.00
# Algeria                         37612070 16,779,265.00 544,860.00
# ...                                  ...           ...        ...
# West Bank and Gaza              37520235 17,976,110.00 178,892.00
# Yemen                           37352574    506,009.00 144,616.00
# Zambia                          37582345  5,391,390.00  95,367.00
# Zimbabwe                        37569033  3,071,659.00  96,985.00
# occupied Palestinian territory     38803         25.00       0.00
#
#                                    Recovered
# Region
#  Azerbaijan                             0.00
# ('St. Martin',)                         0.00
# ...

# %%
pd.options.display.float_format = '{:,.2f}'.format # 2 decimal place formatting 
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False) # Showing results from Highest to Lowest
# Out:
# Region
# US                      3,201,291,312.00
# India                   1,705,855,807.00
# Brazil                  1,417,934,579.00
# Russia                    511,040,684.00
# France                    395,738,242.00
#                               ...
# Republic of the Congo               1.00
# North Ireland                       1.00
# East Timor                          1.00
# Channel Islands                     1.00
#  Azerbaijan                         1.00
# Name: Confirmed, Length: 227, dtype: float64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=True) # sorting lowest to highest confirmed cases
# Out:
# Region
#  Azerbaijan                         1.00
# Channel Islands                     1.00
# East Timor                          1.00
# North Ireland                       1.00
# Republic of the Congo               1.00
#                               ...
# France                    395,738,242.00
# Russia                    511,040,684.00
# Brazil                  1,417,934,579.00
# India                   1,705,855,807.00
# US                      3,201,291,312.00
# Name: Confirmed, Length: 227, dtype: float64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(10) # top 10 confirmed
# Out:
# Region
# US          3,201,291,312.00
# India       1,705,855,807.00
# Brazil      1,417,934,579.00
# Russia        511,040,684.00
# France        395,738,242.00
# UK            385,499,227.00
# Spain         340,195,388.00
# Italy         297,719,949.00
# Colombia      272,628,329.00
# Argentina     258,275,331.00
# Name: Confirmed, dtype: float64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum() # Displaying Confirmed cases with Recovered
# Out:
# <ipython-input-158-d10a379357a6>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered'].sum() # Displaying Confirmed cases with Recovered
#                                    Confirmed     Recovered
# Region
#  Azerbaijan                             1.00          0.00
# ('St. Martin',)                         2.00          0.00
# Afghanistan                    11,651,049.00  8,710,952.00
# Albania                         8,319,315.00  4,803,229.00
# Algeria                        16,779,265.00 11,373,181.00
# ...                                      ...           ...
# West Bank and Gaza             17,976,110.00 15,226,678.00
# Yemen                             506,009.00    303,050.00
# Zambia                          5,391,390.00  4,771,166.00
# Zimbabwe                        3,071,659.00  2,404,400.00
# ...

# %%
data.head(2)
# Out:
#    SNo ObservationDate    State          Region      Last Update  Confirmed  \
# 0    1      01/22/2020    Anhui  Mainland China  1/22/2020 17:00       1.00
# 1    2      01/22/2020  Beijing  Mainland China  1/22/2020 17:00      14.00
#
#    Deaths  Recovered
# 0    0.00       0.00
# 1    0.00       0.00

# %%
data[data.Confirmed<10] # Confirmed cases less than 10
# Out:
#            SNo ObservationDate              State          Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# 6            7      01/22/2020            Guangxi  Mainland China
# ...        ...             ...                ...             ...
# 235956  235957      02/27/2021            Unknown  Mainland China
# 235957  235958      02/27/2021            Unknown          Mexico
# 235960  235961      02/27/2021            Unknown           Spain
# 235961  235962      02/27/2021            Unknown              UK
# 235991  235992      02/27/2021  Wallis and Futuna          France
#
#                 Last Update  Confirmed  Deaths    Recovered
# 0           1/22/2020 17:00       1.00    0.00         0.00
# ...

# %%
data =data[~(data.Confirmed<10)] #removing cases less than 10

# %%
data
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 1            2      01/22/2020            Beijing  Mainland China
# 5            6      01/22/2020          Guangdong  Mainland China
# 13          14      01/22/2020              Hubei  Mainland China
# 34          35      01/22/2020           Zhejiang  Mainland China
# 39          40      01/23/2020            Beijing  Mainland China
# ...        ...             ...                ...             ...
# 236012  236013      02/27/2021  Zaporizhia Oblast         Ukraine
# 236013  236014      02/27/2021            Zeeland     Netherlands
# 236014  236015      02/27/2021           Zhejiang  Mainland China
# 236015  236016      02/27/2021    Zhytomyr Oblast         Ukraine
# 236016  236017      02/27/2021       Zuid-Holland     Netherlands
#
#                 Last Update  Confirmed   Deaths  Recovered
# 1           1/22/2020 17:00      14.00     0.00       0.00
# ...

# %%
data = pd.read_csv(r"C:\Users\27823\Downloads\archive\covid_19_data.csv") #loading unaltered data

# %%
data.groupby('Region')['Deaths'].sum().sort_values(ascending=False) # Finding out which region had the most Deaths
# Out:
# Region
# US                               72,223,008.00
# Brazil                           40,013,970.00
# India                            26,087,127.00
# Mexico                           24,061,279.00
# UK                               17,619,595.00
#                                       ...
# Palestine                                 0.00
# Cambodia                                  0.00
# Republic of Ireland                       0.00
# Reunion                                   0.00
# occupied Palestinian territory            0.00
# Name: Deaths, Length: 197, dtype: float64

# %%
 data.groupby('')['Deaths'].sum().sort_values(ascending=True).head(50) # Finding out which region had the least Deaths
# Out:
# Region
# occupied Palestinian territory          0.00
# Reunion                                 0.00
# Republic of Ireland                     0.00
# Cambodia                                0.00
# Palestine                               0.00
# Laos                                    0.00
# Saint Kitts and Nevis                   0.00
# Guadeloupe                              0.00
# Holy See                                0.00
# Dominica                                0.00
# Solomon Islands                         0.00
# French Guiana                           0.00
# Macau                                   0.00
# Timor-Leste                             0.00
# Martinique                              6.00
# Bhutan                                 51.00
# Grenada                                56.00
# Mongolia                              113.00
# Saint Vincent and the Grenadines      167.00
# Others                                189.00
# Seychelles                            279.00
# ...

# %%
data[data.Region=='South Africa'].sort_values(by='Deaths',ascending=False).head(1) #displaying how many deaths have been recorded thus far in South Africa according to the dataset
# Out:
#            SNo ObservationDate State        Region          Last Update  \
# 235396  235397      02/27/2021   NaN  South Africa  2021-02-28 05:22:20
#
#           Confirmed    Deaths    Recovered
# 235396 1,512,225.00 49,941.00 1,429,047.00
